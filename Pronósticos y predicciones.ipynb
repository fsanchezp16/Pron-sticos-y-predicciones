# %% [markdown]
# # ¡Hola Francisco! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Franciscohas realizado un análisis exploratorio de datos (EDA) muy apropiado, estudiando de manera cuidadosa la distribución de los datos y sus correlaciones, lo cual proporciona una base sólida para el análisis posterior.
#
# En cuanto al entrenamiento de modelos, has implementado correctamente los modelos de clasificación, utilizando métricas relevantes. Sin embargo, para enriquecer tu análisis, te sugiero incluir herramientas adicionales como la matriz de confusión, ya que estas métricas te permitirán comprender mejor el rendimiento específico del modelo para cada categoría.
#
# En lo que respecta a la identificación de clusters de usuarios, has realizado un trabajo acertado en la caracterización de los diferentes grupos, lo cual contribuye a una mejor comprensión de los patrones de comportamiento. Recuerda que cada aspecto del análisis de datos es una oportunidad para profundizar tu comprensión y que la exploración de diferentes métricas y técnicas te ayudará a desarrollar una visión más completa y robusta en tus proyectos futuros.
#
# Mi única recomendación es que recuerdes que es crucial incluir tus análisis en cada sección o parte de información (tabla, gráfica, etc) que obtengas. Un proyecto en el contexto de ciencia o análisis de datos va más allá de escribir código y obtener valores; se trata de darles sentido y contexto para convertirlos en conocimiento útil. Este proceso permite tomar decisiones informadas, optimizar modelos y comunicar hallazgos de manera clara y efectiva, asegurando que el análisis no solo sea técnico, sino también comprensible y aplicable a la resolución de problemas reales.
#
# Te deseo éxitos en tu próximo Sprint 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# # SPRINT 13

# %% [markdown]
# .

# %% [markdown]
# # Paso 1, Cargar datos

# %%
import pandas as pd
df = pd.read_csv('/datasets/gym_churn_us.csv')

# %%
df.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
df.describe()
# Out:
#             gender  Near_Location      Partner  Promo_friends        Phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        Contract_period  Group_visits          Age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# .

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo importando las librerías y los datos del proyecto. Adicionalmente usaste correctamente las funciones `info`, `describe` y `head`, esto te permite hacer una primera revisión de los datos, su estructura y contenido. Con esta información, podemos establecer una hoja de ruta para ajustar, modificar y analizar los datos de una manera adecuada.
#
#
# </div>

# %% [markdown]
# # Paso 2, Análisis exploratorio de datos (EDA)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Al importar librerías en un notebook de Python, una buena práctica es incluir en la primera celda todas las que vas a emplear en el proyecto, organizándolas por orden de importancia o categorías.
#
# </div>

# %%
#Revisar valores ausentes
df.isna().sum()
# Out:
# gender                               0
# Near_Location                        0
# Partner                              0
# Promo_friends                        0
# Phone                                0
# Contract_period                      0
# Group_visits                         0
# Age                                  0
# Avg_additional_charges_total         0
# Month_to_end_contract                0
# Lifetime                             0
# Avg_class_frequency_total            0
# Avg_class_frequency_current_month    0
# Churn                                0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo comprobando la presencia de datos faltantes, esto es clave para evitar errores en el análisis de los datos
#
# </div>

# %%
#Agrupar por 'Churn' y ver promedios
df.groupby('Churn').mean()
# Out:
#          gender  Near_Location   Partner  Promo_friends     Phone  \
# Churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        Contract_period  Group_visits        Age  Avg_additional_charges_total  \
# Churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        Month_to_end_contract  Lifetime  Avg_class_frequency_total  \
# Churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        Avg_class_frequency_current_month
# Churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# .

# %%
# Histograma por grupo de cancelación
for column in df.drop(columns='Churn').select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(data=df, x=column, hue='Churn', kde=True, element='step', stat='density', common_norm=False)
    plt.title(f'Distribución de {column} por cancelación')
    plt.show()

# %% [markdown]
# .

# %%
# Matriz de correlación
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Matriz de correlación')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Las gráficas que has obtenido son correctas, pero es crucial acompañarla con tu análisis y observaciones. Esto añade valor significativo a la información presentada y evita que solo sean datos sin contexto. Desarrollar esta capacidad de interpretación es esencial cuanto estamos trabajando con datos.
#
# </div>

# %% [markdown]
# .

# %% [markdown]
# # Paso 3, Modelo para predecir cancelación de usuarios

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, classification_report, roc_curve
import matplotlib.pyplot as plt

# %%
# Separar features y variable objetivo
X = df.drop(columns=['Churn'])
y = df['Churn']

# %%
# Convertir variables categóricas (si hay)
X = pd.get_dummies(X, drop_first=True)

# %%
# Dividir en entrenamiento y validación
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Estandarizar datos para regresión logística
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)

# %%
# Modelo 1: Regresión logística
log_model = LogisticRegression(random_state=42)
log_model.fit(X_train_scaled, y_train)
log_preds = log_model.predict(X_valid_scaled)
log_probs = log_model.predict_proba(X_valid_scaled)[:, 1]

# %%
# Modelo 2: Bosque Aleatorio
forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
forest_model.fit(X_train, y_train)
forest_preds = forest_model.predict(X_valid)
forest_probs = forest_model.predict_proba(X_valid)[:, 1]

# %%
# Evaluación de ambos modelos
def print_metrics(name, y_true, y_pred, y_probs):
    print(f"\n--- {name} ---")
    print(f"Accuracy:  {accuracy_score(y_true, y_pred):.3f}")
    print(f"Precision: {precision_score(y_true, y_pred):.3f}")
    print(f"Recall:    {recall_score(y_true, y_pred):.3f}")
    print(f"ROC AUC:   {roc_auc_score(y_true, y_probs):.3f}")

# %%
print_metrics("Regresión Logística", y_valid, log_preds, log_probs)
print_metrics("Bosque Aleatorio", y_valid, forest_preds, forest_probs)
# Out:
# --- Regresión Logística ---
# Accuracy:  0.924
# Precision: 0.883
# Recall:    0.806
# ROC AUC:   0.974
#
# --- Bosque Aleatorio ---
# Accuracy:  0.916
# Precision: 0.866
# Recall:    0.791
# ROC AUC:   0.965

# %%
# Curva ROC
fpr_log, tpr_log, _ = roc_curve(y_valid, log_probs)
fpr_forest, tpr_forest, _ = roc_curve(y_valid, forest_probs)

plt.figure(figsize=(8, 6))
plt.plot(fpr_log, tpr_log, label='Regresión Logística')
plt.plot(fpr_forest, tpr_forest, label='Bosque Aleatorio')
plt.plot([0, 1], [0, 1], '--', color='gray')
plt.xlabel('Falsos Positivos')
plt.ylabel('Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Buen trabajo Francisco! Tu código está muy bien estructurado y sigue un flujo lógico claro para la preparación de datos, entrenamiento de modelos y evaluación. Has aplicado correctamente el preprocesamiento necesario para la regresión logística y comparado dos modelos usando métricas clave.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Una recomendación sería aplicar también la estandarización a los datos usados en el modelo de bosque aleatorio, aunque no siempre es necesario, puede ayudar si decides probar otros algoritmos sensibles a la escala.
#
# Asimismo, puedes complementar la evaluación de tus modelos empleando una matriz de confusión, ya que proporciona una visión detallada de los aciertos y errores del modelo al clasificar las distintas clases.
#
# Finalmente, recuerda siempre incluir tu interpretación de la información obtenida para que tu trabajo no se quede solo en código, sino que se convierta en una herramienta clave para la toma de decisiones.
#
# </div>
#
# </div>

# %% [markdown]
# .

# %% [markdown]
# # Paso 4, Crear clúster de usuarios/as

# %%
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
import numpy as np

# %%
# Eliminar la columna objetivo
features = df.drop(columns=['Churn'])

# %%
# Convertir variables categóricas
features = pd.get_dummies(features, drop_first=True)

# %%
# Estandarizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# %%
# Crear dendrograma para estimar número de clústeres
linked = linkage(X_scaled, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(linked, truncate_mode='level', p=5)
plt.title('Dendrograma de usuarios')
plt.xlabel('Índice del cliente')
plt.ylabel('Distancia')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo creando el dendrograma. De manera específica tu gráfico muestra la agrupación jerárquica de los datos, donde se observan varias uniones a diferentes niveles de distancia.
#
#
# </div>

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# Añadir los clústeres al dataframe original
df['cluster'] = clusters

# %%
# Promedios por clúster
cluster_profiles = df.groupby('cluster').mean()
print(cluster_profiles)
# Out:
#            gender  Near_Location   Partner  Promo_friends  Phone  \
# cluster
# 0        0.502370       0.949447  0.829384       0.998420    1.0
# 1        0.554556       0.849269  0.263217       0.052868    1.0
# 2        0.499422       0.937572  0.737572       0.478613    1.0
# 3        0.485738       0.718011  0.299919       0.018745    1.0
# 4        0.523316       0.862694  0.471503       0.305699    0.0
#
#          Contract_period  Group_visits        Age  \
# cluster
# 0               3.097946      0.448657  29.104265
# 1               2.606299      0.436445  30.008999
# 2              11.854335      0.546821  29.905202
# 3               1.914425      0.276284  28.083945
# 4               4.777202      0.427461  29.297927
#
#          Avg_additional_charges_total  Month_to_end_contract  Lifetime  \
# cluster
# 0                          141.774331               2.887836  3.772512
# 1                          159.774265               2.419573  4.780652
# ...

# %%
# Distribución de clústeres
plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='cluster')
plt.title('Distribución de clientes por clúster')
plt.show()

# %%
# Tasa de cancelación por clúster
churn_by_cluster = df.groupby('cluster')['Churn'].mean()
print("\nTasa de cancelación por clúster:")
print(churn_by_cluster)
# Out:
# Tasa de cancelación por clúster:
# cluster
# 0    0.246445
# 1    0.089989
# 2    0.021965
# 3    0.572942
# 4    0.266839
# Name: Churn, dtype: float64

# %%
# Visualización
plt.figure(figsize=(8, 4))
churn_by_cluster.plot(kind='bar', color='blue')
plt.ylabel('Tasa de cancelación')
plt.title('Tasa de cancelación por clúster')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Excelente trabajo aplicando K-Means para segmentar a los usuarios! Tu código está muy completo: seleccionaste un número razonable de clústeres, integraste los resultados al dataframe original y analizaste los perfiles promedio y la tasa de cancelación por clúster de forma clara.
#
# </div>

# %% [markdown]
# .

# %% [markdown]
# # Paso 5, Conlcusiones y recomendaciones sobre trabajo con los clientes

# %% [markdown]
# Basado en el análisis exploratorio, modelado predictivo y segmentación por clústeres, se muestran las siguientes conclusiones clave y recomendaciones:
#
# Los factores que más relación tienen en las cancelaciones son los sisguientes:
# - Un lifetime corto para nuevos usuarios, lo cual hace que la probabilidad de cancelar de los usuarios sea mayor.
# - Baja frecuencia de visitas,  tanto histórica como del mes actual.
# - Usuarios con contratos cortos, como los de 1 mes, tienen mayor rotación que los usuarios de contratos largos, entre 6 o 12 meses.
# - Los clientes que no participan en clases grupales o no consumen servicios adicionales también cancelan con más frecuencia.
#
# Otra de las conclusiones después de hacer el análisis de datos es que el bosque aleatorio ofrece un mejor desempeño general en la regresión logística.
#
# Ambos modelos pueden predecir con buena precisión quién es probable que se cancele.
#
# Se identificaron grupos con tasas de cancelación significativamente distintas.

# %% [markdown]
# En cuanto a las recomendaciones para la retención, se tienen las siguientes:
# - Detectar y actuar sobre los usuarios de riesgo, donde se puede usar el modelo predictivo para identificar con alta probabilidad de churn e implementar campañas de retención específicas como el envío de recordatorios o promociones perzonalizadas.
# - Incentivar clases grupoales y contratos más largos, donde se puede ofrecer descuentos atractivos para pasar de un contrato mensual a uno trimestral o anual y promocionar beneficios de clases grupales, como por ejemplo a más socialización mayor compromiso.
# - Promover el uso de servicios adicionales, ofreciendo paquetes combinados que incluyan entretenimiento, nutrición o spa y dar recompensas por gastar más en el gimnasio, como programa de puntos o beneficios exclusivos.
# - Segmentación de campañas de marketing, creando mensajes específicos por cluster como 'clientes nuevos' o 'clientes premium' y enforcar los recursos de retención en los clúster con mayor tasa de cancelación.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Francisco tu conclusión logra integrar con claridad los hallazgos del análisis de datos, el modelado predictivo y la segmentación, destacando patrones relevantes que explican la cancelación de clientes. Es valioso cómo identificas factores específicos de riesgo como la duración del contrato, la participación en servicios adicionales y la frecuencia de visitas, y los conectas con acciones concretas. Además, reconoces de forma acertada el mejor desempeño del modelo de bosque aleatorio y lo vinculas a su utilidad práctica para la retención de usuarios.
#
# </div>
